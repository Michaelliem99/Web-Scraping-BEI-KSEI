# %% [markdown]
# Code History:
# 1. Version 1.0 (2023/03/09):
#     - Base version, working as expected
# 2. Version 1.1 (2023/03/19):
#     - Everytime **Financial Report Links** code runs, it won't overwrite any previous data, instead it will append new data for the previous scraped data.

# %% [markdown]
# <strong>Features:</strong>
# - Scrape IDX individual stock summary and details
# - Scrape IDX sectoral stock summary and its components
# - Scrape IDX stock index summary
#
# Plan: Data is scraped <strong>every weekday on 6PM GMT+7</strong>, few hours after the market has closed for the day. So the data you see before 6PM is previous trading day data.

# %%
import json
from json.decoder import JSONDecodeError
import pandas as pd
import time
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import threading
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm

# %% [markdown]
# # Chrome Selenium Starter
#
# Why Selenium? Because I need it to bypass cloudfare restriction

# %%
# Initialize the Chrome driver
options = Options()
options.add_argument("--headless=new")
driver = webdriver.Chrome(options=options)

# %% [markdown]
# # Scrape Summary URL

# %% [markdown]
# ## URL List

# %%
urls = {
    'BEIStockSummary':'https://www.idx.co.id/primary/TradingSummary/GetStockSummary?length=9999&start=0',
    'BEISectoralSummary':'https://www.idx.co.id/primary/StockData/GetIndexIC',
    'BEIIndexSummary':'https://www.idx.co.id/primary/StockData/GetConstituent'
}

# %% [markdown]
# ## BEI Stock Summary

# %%
driver.get(urls['BEIStockSummary'])
WebDriverWait(driver, timeout=10).until(lambda d: d.find_element(By.TAG_NAME, 'body'))
BEIStockSummaryContent = driver.find_element(By.TAG_NAME, value='body').text
time.sleep(2)

# %%
BEIStockSummaryDF = pd.DataFrame(json.loads(BEIStockSummaryContent)['data']).drop(columns=['No'])
BEIStockSummaryDF
# Out:
#      IDStockSummary                 Date StockCode  \
# 0           3298117  2023-03-17T00:00:00      AALI
# 1           3298118  2023-03-17T00:00:00      ABBA
# 2           3298119  2023-03-17T00:00:00      ABDA
# 3           3298120  2023-03-17T00:00:00      ABMM
# 4           3298121  2023-03-17T00:00:00      ACES
# ..              ...                  ...       ...
# 850         3298967  2023-03-17T00:00:00      ZATA
# 851         3298968  2023-03-17T00:00:00      ZBRA
# 852         3298969  2023-03-17T00:00:00      ZINC
# 853         3298970  2023-03-17T00:00:00      ZONE
# 854         3298971  2023-03-17T00:00:00      ZYRX
#
#                         StockName                         Remarks  Previous  \
# 0         Astra Agro Lestari Tbk.  --M-18AEM16000D232------------    7875.0
# 1               Mahaka Media Tbk.  --U-2100000000E614------------      92.0
# 2    Asuransi Bina Dana Arta Tbk.  --U-2105000000G412------------    6475.0
# 3              ABM Investama Tbk.  --M-1835000000C311------------    2640.0
# 4     Ace Hardware Indonesia Tbk.  --MO1S35MD0000E743------------     440.0
# ..                            ...                             ...       ...
# 850       Bersama Zatta Jaya Tbk.  --U-1130000000E741------------      60.0
# 851     Dosni Roha Indonesia Tbk.  --U-2135000000C311------------     492.0
# 852        Kapuas Prima Coal Tbk.  --U-2105000000B146------------      50.0
# 853            Mega Perintis Tbk.  --M-2135000000E741------------    1150.0
# 854  Zyrexindo Mandiri Buana Tbk.  --U-2130000000I221------------     286.0
#
#      OpenPrice  FirstTrade    High     Low  ...  TradebleShares  \
# 0          0.0         0.0  8000.0  7875.0  ...    1.924688e+09
# 1          0.0         0.0   101.0    87.0  ...    3.935893e+09
# 2          0.0         0.0     0.0     0.0  ...    6.208067e+08
# 3          0.0         0.0  2740.0  2650.0  ...    2.753165e+09
# 4        442.0       444.0   454.0   442.0  ...    1.715000e+10
# ..         ...         ...     ...     ...  ...             ...
# 850        0.0         0.0    63.0    56.0  ...    1.700000e+09
# 851        0.0         0.0   496.0   488.0  ...    2.510706e+09
# 852        0.0         0.0    50.0    50.0  ...    2.525000e+10
# 853        0.0         0.0  1160.0  1145.0  ...    8.701715e+08
# 854        0.0         0.0   300.0   286.0  ...    1.333334e+09
#
#      WeightForIndex  ForeignSell  ForeignBuy  DelistingDate  NonRegularVolume  \
# 0      3.907117e+08     869300.0    262900.0                            958.0
# 1      1.342139e+09          0.0         0.0                              0.0
# 2      3.147490e+07          0.0         0.0                              0.0
# 3      5.688039e+08     160800.0     72100.0                              0.0
# 4      6.832560e+09   12230400.0  26713300.0                              0.0
# ..              ...          ...         ...            ...               ...
# 850    1.099382e+09      40000.0    133200.0                              0.0
# 851    4.245604e+08          0.0    195300.0                              0.0
# 852    7.456325e+09          0.0         0.0                              0.0
# 853    1.161679e+08          0.0         0.0                              0.0
# 854    3.333335e+08          0.0         0.0                              0.0
#
#      NonRegularValue  NonRegularFrequency  persen  percentage
# 0          7621500.0                 11.0    None        None
# 1                0.0                  0.0    None        None
# 2                0.0                  0.0    None        None
# 3                0.0                  0.0    None        None
# 4                0.0                  0.0    None        None
# ..               ...                  ...     ...         ...
# 850              0.0                  0.0    None        None
# 851              0.0                  0.0    None        None
# 852              0.0                  0.0    None        None
# 853              0.0                  0.0    None        None
# 854              0.0                  0.0    None        None
#
# [855 rows x 31 columns]

# %% [markdown]
# ## Close and Quit Driver

# %%
driver.quit()

# %% [markdown]
# # Scrape Stock Details URL

# %% [markdown]
# ## Company Profiles

# %%
def get_company_profiles(driver, stock):
    while True:
        try:
            company_profiles_url = 'https://www.idx.co.id/primary/ListedCompany/GetCompanyProfilesDetail?KodeEmiten=' + stock
            driver.get(company_profiles_url)

            WebDriverWait(driver, timeout=10).until(lambda d: d.find_element(By.TAG_NAME, 'body'))

            CompanyProfilesContent = driver.find_element(By.TAG_NAME, value='body').text
            CompanyProfilesRow = pd.DataFrame(json.loads(CompanyProfilesContent)['Profiles'])
            CompanyProfilesRow.insert(0, 'StockCode', stock)
            
            break
        except JSONDecodeError as e:
            time.sleep(1.5)
#             print(stock, 'Company Profiles JSON is not available!', 'Retrying!')
    
    time.sleep(1)    
    
    return CompanyProfilesRow

# %% [markdown]
# ## Today Trading Info

# %%
def get_today_trading_info(driver, stock):
    while True:
        try:
            trading_info_url = 'https://www.idx.co.id/primary/ListedCompany/GetTradingInfoSS?code={}&start=0&length=10000'.format(stock)
            driver.get(trading_info_url)

            WebDriverWait(driver, timeout=10).until(lambda d: d.find_element(By.TAG_NAME, 'body'))

            TradingInfoContent = driver.find_element(By.TAG_NAME, value='body').text
            TradingInfoRows = pd.DataFrame(json.loads(TradingInfoContent)['replies'])
            
            break
        except JSONDecodeError as e:
            time.sleep(1.5)
#             print(stock, 'Trading Info JSON is not available!', 'Retrying!')
    
    time.sleep(1)
    
    return TradingInfoRows

# %% [markdown]
# ## Financial Reports File Links
# Maximum last 2 years (Current: 2023, Min: 2022)
#
# Code will only find for any missing data, previous available data won't be overwritten.

# %%
def get_financial_report_file_links(driver, stock, prev_financial_report):
    current_year = datetime.now().year
    # last 2 years
    years = [current_year, current_year-1]
    periods = ['TW1', 'TW2', 'TW3', 'Audit']
    
    FinancialReportRows = pd.DataFrame()

    for year in years:
        for period in periods:
            if len(prev_financial_report_stock[(prev_financial_report_stock['Report_Period'] == period) & (prev_financial_report_stock['Report_Year'] == year)]) > 0:
                continue
            else:
                while True:
                    try:
                        financial_report_url = 'https://www.idx.co.id/primary/ListedCompany/GetFinancialReport?periode={}&year={}&indexFrom=0&pageSize=1000&reportType=rdf&kodeEmiten={}'.format(period, year, stock)
                        driver.get(financial_report_url)

                        WebDriverWait(driver, timeout=10).until(lambda d: d.find_element(By.TAG_NAME, 'body'))

                        FinancialReportContent = driver.find_element(By.TAG_NAME, value='body').text

                        if json.loads(FinancialReportContent)['ResultCount'] > 0:
                            FinancialReportRow = pd.DataFrame(json.loads(FinancialReportContent)['Results'][0]['Attachments'])
                            FinancialReportRow = FinancialReportRow.rename(columns={'Emiten_Code':'StockCode'})
                            FinancialReportRows = pd.concat([FinancialReportRows, FinancialReportRow])

                        break
                    except JSONDecodeError as e:
                        time.sleep(1.5)
    #                     print(stock, year, period, 'JSON is not available!', 'Retrying!')

        time.sleep(2)

    return FinancialReportRows

# %% [markdown]
# ## Multithreading Scrape

# %% [markdown]
# ### Worker Function

# %%
# Define a worker function that takes stock codes from the queue and loads them in parallel
def load_stock(stock, prev_financial_report_stock):
    options = Options()
    options.add_argument("--headless=new")
    driver = webdriver.Chrome(options=options)

    company_profiles = get_company_profiles(driver, stock)
    today_trading_info = get_today_trading_info(driver, stock)
    financial_report_links = get_financial_report_file_links(driver, stock, prev_financial_report_stock)
    
    return company_profiles, today_trading_info, financial_report_links

# %% [markdown]
# ### Create list to store scraped data

# %%
prev_financial_report_df = pd.read_excel('stocks.xlsx', sheet_name='Financial Reports')

# %%
results = {
    'CompanyProfiles':[],
    'TodayTradingInfo':[],
    'FinancialReportLinks':[]
}

# %%
prev_financial_report_df = pd.read_excel('stocks.xlsx', sheet_name='Financial Reports')

with tqdm(total=len(BEIStockSummaryDF['StockCode'])) as pbar:
    with ThreadPoolExecutor(max_workers=7) as executor:
        futures = []

        for StockCode in BEIStockSummaryDF['StockCode']:
            prev_financial_report_stock = prev_financial_report_df[prev_financial_report_df['StockCode'] == StockCode]
            future = executor.submit(load_stock, StockCode, prev_financial_report_stock)
            futures.append(future)
            
        for future in as_completed(futures):
            pbar.update(1)
            company_profiles, today_trading_info, financial_report_links = future.result()
            results['CompanyProfiles'].append(company_profiles)
            results['TodayTradingInfo'].append(today_trading_info)
            results['FinancialReportLinks'].append(financial_report_links)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 855/855 [26:43<00:00,  1.88s/it]

# %% [markdown]
# ## Join All Stock Details

# %%
CompanyProfilesDF = pd.concat(results['CompanyProfiles']).reset_index(drop=True).drop(
    columns=[
        'DataID', 'Divisi', 'EfekEmiten_EBA', 'EfekEmiten_ETF', 
        'EfekEmiten_Obligasi', 'EfekEmiten_SPEI', 'EfekEmiten_Saham',
        'id', 'KodeDivisi', 'JenisEmiten', 'KodeEmiten', 'Status'
    ]
)
CompanyProfilesDF['TanggalPencatatan'] = pd.to_datetime(CompanyProfilesDF['TanggalPencatatan']).dt.normalize()
CompanyProfilesDF['Logo'] = ['https://www.idx.co.id' + logo for logo in CompanyProfilesDF['Logo']]
CompanyProfilesDF['LastScraped'] = datetime.now()
CompanyProfilesDF
# Out:
#     StockCode                                             Alamat  \
# 0        ADCP  Jl. Pengantin Ali No. 88, Ciracas\r\nKota Jaka...
# 1        ADES  Jl. Let. Jend. TB Simatupang No. 89, RT 01 RW ...
# 2        ABMM  Gedung TMT 1 Lantai 18 Jl. Cilandak KKO No. 1 ...
# 3        ABBA  Sahid Sudirman Centre Lt. 10, Jl. Jend. Sudirm...
# 4        AALI  Jl Pulo Ayang Raya Blok OR No. 1\r\nKawasan In...
# ..        ...                                                ...
# 847      ZATA  Komplek Industri Prapanca No.24, Cigondewah Ka...
# 848      ZBRA  Satrio Tower Lt. 23, Jl. Prof Dr. Satrio Kav. ...
# 849      ZONE  Jalan Karet Pedurenan No. 240, Karet Kuningan,...
# 850      ZINC  Jl. Pantai Indah Selatan I, Elang Laut Blok A ...
# 851      ZYRX  Jl. Daan Mogot No.59\r\nTanjung Duren Utara, G...
#
#                            BAE                           Industri  \
# 0                               Pengelola & Pengembang Real Estat
# 1      PT. Raya Saham Registra                            Minuman
# 2         PT. Datindo Entrycom    Perusahaan Holding Multi-sektor
# 3    PT. Adimitra Jasa Korpora                              Media
# 4      PT. Raya Saham Registra           Produk Makanan Pertanian
# ..                         ...                                ...
# 847  PT. Adimitra Jasa Korpora                       Ritel Khusus
# 848           PT BSR Indonesia    Perusahaan Holding Multi-sektor
# 849          PT. Bima Registra                       Ritel Khusus
# 850                                               Logam & Mineral
# 851  PT. Adimitra Jasa Korpora                 Perangkat Komputer
#
#                           SubIndustri  \
# 0    Pengembang & Operator Real Estat
# 1                      Minuman Ringan
# 2     Perusahaan Holding Multi-sektor
# 3                          Penerbitan
# 4         Perkebunan & Tanaman Pangan
# ..                                ...
# 847           Ritel Pakaian & Tekstil
# 848   Perusahaan Holding Multi-sektor
# 849           Ritel Pakaian & Tekstil
# 850           Logam & Mineral Lainnya
# 851                Perangkat Komputer
#
#                                        Email                           Fax  \
# 0                          corsec@adcp.co.id              (021) 228 220 81
# 1         wisnu.adji@akashainternational.com      021 - 78845549; 78845547
# 2    corporate.secretary@abm-investama.co.id                  021-29976768
# 3                         corsec@mahakax.com                (021) 573 9210
# 4                  Investor@astra-agro.co.id  461-6655, 461-6677, 461-6688
# ..                                       ...                           ...
# 847                    corporate@elcorps.com
# 848               legal@zebranusantara.co.id               (021) 2788 3914
# 849               corpsec@megaperintis.co.id               (021) 5290 5103
# 850                         corsec@ptkpc.com                021 - 29676234
# 851                         corsec@zyrex.com                  (021)5653322
#
#                                     KegiatanUsahaUtama  \
# 0                           Perhotelan dan Real Estate
# 1                          Minuman dan  Makanan Ringan
# 2    berupa jasa penyewaan namun tidak terbatas pad...
# 3                                 Media dan Percetakan
# 4                               Agriculture Plantation
# ..                                                 ...
# 847  Aktivitas Perusahaan Holding dan aktivitas Usa...
# 848  Perusahaan Holding dan Angkutan Bermotor untuk...
# 849                                 Perdagangan retail
# 850                       Pertambangan dan Perdagangan
# 851                  Bidang komputer dan jasa komputer
#
#                              NamaEmiten                           NPKP  \
# 0         PT Adhi Commuter Properti Tbk
# 1    Akasha Wira International Tbk  Tbk                              -
# 2                     ABM Investama Tbk  PEM-01535/WPJ.04/KP.1003/2008
# 3                      Mahaka Media Tbk                              0
# 4                Astra Agro Lestari Tbk
# ..                                  ...                            ...
# 847           PT Bersama Zatta Jaya Tbk
# 848         PT Dosni Roha Indonesia Tbk
# 849               PT Mega Perintis Tbk.
# 850            PT Kapuas Prima Coal Tbk
# 851      PT Zyrexindo Mandiri Buana Tbk
#
#                      NPWP PapanPencatatan                      Sektor  \
# 0    85.227.029.7-093.000           Utama       Properti & Real Estat
# 1    01.371.491.0-054.000    Pengembangan      Barang Konsumen Primer
# 2    02.504.191.4-054.000           Utama               Perindustrian
# 3    01.609.052.4-054.000    Pengembangan  Barang Konsumen Non-Primer
# 4    01.334.427.0-054.000           Utama      Barang Konsumen Primer
# ..                    ...             ...                         ...
# 847  31.569.863.9-428.000           Utama  Barang Konsumen Non-Primer
# 848  01.451.869.0-054.000    Pengembangan               Perindustrian
# 849  02.433.917.8-011.000    Pengembangan  Barang Konsumen Non-Primer
# 850  02.386.972.0-091.000    Pengembangan                 Barang Baku
# 851  01.771.960.0-038.000    Pengembangan                   Teknologi
#
#                                  SubSektor TanggalPencatatan  \
# 0                    Properti & Real Estat        2021-05-21
# 1                        Makanan & Minuman        1994-06-13
# 2          Perusahaan Holding Multi Sektor        2011-12-06
# 3                          Media & Hiburan        2002-04-03
# 4                        Makanan & Minuman        1997-12-09
# ..                                     ...               ...
# 847                      Perdagangan Ritel        2022-11-10
# 848        Perusahaan Holding Multi Sektor        1991-08-01
# 849                      Perdagangan Ritel        2018-12-12
# 850                            Barang Baku        2017-10-16
# 851  Perangkat Keras & Peralatan Teknologi        2021-03-30
#
#                              Telepon                      Website  \
# 0                   (021) 228 229 80               www.adcp.co.id
# 1                       081119345000  www.akashainternational.com
# 2                       021-29976767        www.abm-investama.com
# 3                     (021) 573 9203              www.mahakax.com
# 4                          461-65-55  http://www.astra-agro.co.id
# ..                               ...                          ...
# 847                   (022) 86017900              www.elcorps.com
# 848                  (021) 2788 3900     www.zebranusantara.co.id
# 849  (021) 5733 888; (021) 5290 4379       www.megaperintis.co.id
# 850                   021 - 29676236                www.ptkpc.com
# 851                    (021) 5653311             http://zyrex.com
#
#                                                   Logo  \
# 0    https://www.idx.co.id/Portals/0/StaticData/Lis...
# 1    https://www.idx.co.id/Portals/0/StaticData/Lis...
# 2    https://www.idx.co.id/Portals/0/StaticData/Lis...
# 3    https://www.idx.co.id/Portals/0/StaticData/Lis...
# 4    https://www.idx.co.id/Portals/0/StaticData/Lis...
# ..                                                 ...
# 847  https://www.idx.co.id/Portals/0/StaticData/Lis...
# 848  https://www.idx.co.id/Portals/0/StaticData/Lis...
# 849  https://www.idx.co.id/Portals/0/StaticData/Lis...
# 850  https://www.idx.co.id/Portals/0/StaticData/Lis...
# 851  https://www.idx.co.id/Portals/0/StaticData/Lis...
#
#                    LastScraped
# 0   2023-03-19 20:14:57.589306
# 1   2023-03-19 20:14:57.589306
# 2   2023-03-19 20:14:57.589306
# 3   2023-03-19 20:14:57.589306
# 4   2023-03-19 20:14:57.589306
# ..                         ...
# 847 2023-03-19 20:14:57.589306
# 848 2023-03-19 20:14:57.589306
# 849 2023-03-19 20:14:57.589306
# 850 2023-03-19 20:14:57.589306
# 851 2023-03-19 20:14:57.589306
#
# [852 rows x 19 columns]

# %%
prev_trading_info = pd.read_excel('stocks.xlsx', sheet_name='Trading Info')
TradingInfoDF = pd.concat(results['TodayTradingInfo']).drop(columns=['No', 'Remarks']).reset_index(drop=True)
TradingInfoDF['Date'] = pd.to_datetime(TradingInfoDF['Date'])
TradingInfoDF['LastScraped'] = datetime.now()
TradingInfoDF = pd.concat([TradingInfoDF, prev_trading_info]).sort_values(by='Date').drop_duplicates(subset=['StockCode', 'Date'], keep='first').reset_index(drop=True)
TradingInfoDF
# Out:
#         IDStockSummary       Date StockCode  \
# 0              2676848 2020-01-02      RMBA
# 1              2676705 2020-01-02      MAPI
# 2              2676978 2020-01-02      WSKT
# 3              2676465 2020-01-02      CFIN
# 4              2676518 2020-01-02      ELSA
# ...                ...        ...       ...
# 593110         3298603 2023-03-17      MARI
# 593111         3298248 2023-03-17      BMRI
# 593112         3298809 2023-03-17      SDRA
# 593113         3298600 2023-03-17      MAPA
# 593114         3298123 2023-03-17      ADCP
#
#                                      StockName  Previous  OpenPrice  \
# 0         Bentoel Internasional Investama Tbk.     330.0        0.0
# 1                        Mitra Adiperkasa Tbk.    1055.0        0.0
# 2                 Waskita Karya (Persero) Tbk.    1485.0     1485.0
# 3                Clipan Finance Indonesia Tbk.     290.0        0.0
# 4                                  Elnusa Tbk.     306.0        0.0
# ...                                        ...       ...        ...
# 593110               Mahaka Radio Integra Tbk.      76.0        0.0
# 593111             Bank Mandiri (Persero) Tbk.    9850.0     9950.0
# 593112  Bank Woori Saudara Indonesia 1906 Tbk.     570.0        0.0
# 593113               Map Aktif Adiperkasa Tbk.    4520.0        0.0
# 593114             Adhi Commuter Properti Tbk.      59.0        0.0
#
#         FirstTrade     High     Low    Close  ...  ListedShares  \
# 0              0.0    350.0   316.0    316.0  ...  3.640114e+10
# 1              0.0   1070.0  1035.0   1065.0  ...  1.660000e+10
# 2           1485.0   1515.0  1480.0   1505.0  ...  1.357395e+10
# 3              0.0    280.0   270.0    276.0  ...  3.984520e+09
# 4              0.0    310.0   300.0    302.0  ...  7.298500e+09
# ...            ...      ...     ...      ...  ...           ...
# 593110         0.0     88.0    71.0     78.0  ...  5.252644e+09
# 593111      9975.0  10125.0  9925.0  10100.0  ...  4.620000e+10
# 593112         0.0    580.0   570.0    575.0  ...  8.482552e+09
# 593113         0.0   4600.0  4510.0   4600.0  ...  2.850400e+09
# 593114         0.0     60.0    58.0     59.0  ...  2.222222e+10
#
#         TradebleShares  WeightForIndex  ForeignSell  ForeignBuy  \
# 0         3.640114e+10    3.640114e+10          0.0         0.0
# 1         1.660000e+10    1.660000e+10    3216100.0   1185700.0
# 2         1.357395e+10    1.357395e+10     554100.0    770300.0
# 3         3.984520e+09    3.984520e+09      86700.0       500.0
# 4         7.298500e+09    7.298500e+09      13400.0     29300.0
# ...                ...             ...          ...         ...
# 593110    5.252644e+09    1.758060e+09    1105900.0     42300.0
# 593111    4.620000e+10    1.844766e+10   60233600.0  67946400.0
# 593112    8.482552e+09    7.091413e+08          0.0      2300.0
# 593113    2.850400e+09    6.627180e+08     191900.0     78300.0
# 593114    2.222222e+10    2.222222e+09          0.0         0.0
#
#         DelistingDate  NonRegularVolume  NonRegularValue  NonRegularFrequency  \
# 0                                   0.0     0.000000e+00                  0.0
# 1                              478050.0     4.962172e+08                  2.0
# 2                             3281075.0     5.137233e+09                  5.0
# 3                                   0.0     0.000000e+00                  0.0
# 4                                  10.0     3.020000e+03                  1.0
# ...               ...               ...              ...                  ...
# 593110                              0.0     0.000000e+00                  0.0
# 593111                        1740757.0     1.721379e+10                 13.0
# 593112                              0.0     0.000000e+00                  0.0
# 593113                             26.0     1.094600e+05                  1.0
# 593114                              0.0     0.000000e+00                  0.0
#
#                       LastScraped
# 0      2023-03-19 20:14:58.477489
# 1      2023-03-19 20:14:58.477489
# 2      2023-03-19 20:14:58.477489
# 3      2023-03-19 20:14:58.477489
# 4      2023-03-19 20:14:58.477489
# ...                           ...
# 593110 2023-03-19 20:14:58.477489
# 593111 2023-03-19 20:14:58.477489
# 593112 2023-03-19 20:14:58.477489
# 593113 2023-03-19 20:14:58.477489
# 593114 2023-03-19 20:14:58.477489
#
# [593115 rows x 29 columns]

# %%
FinancialReportLinksDF = pd.concat(results['FinancialReportLinks']).reset_index(drop=True).drop(
    columns=['File_ID', 'File_Size', 'File_Type']
)
FinancialReportLinksDF['File_Modified'] = pd.to_datetime(FinancialReportLinksDF['File_Modified']).dt.normalize()
FinancialReportLinksDF['File_Path'] = 'https://www.idx.co.id/' + FinancialReportLinksDF['File_Path']
FinancialReportLinksDF['LastScraped'] = datetime.now()
FinancialReportLinksDF = pd.concat([FinancialReportLinksDF, prev_financial_report_df]).reset_index(drop=True)
FinancialReportLinksDF
# Out:
#       StockCode File_Modified  \
# 0          ADCP    2022-07-29
# 1          ADCP    2022-07-29
# 2          ADCP    2022-07-29
# 3          ADCP    2022-07-29
# 4          ADCP    2022-07-29
# ...         ...           ...
# 27683      ZYRX    2022-12-22
# 27684      ZYRX    2022-12-22
# 27685      ZYRX    2022-12-22
# 27686      ZYRX    2022-12-22
# 27687      ZYRX    2022-12-22
#
#                                                File_Name  \
# 0                    FinancialStatement-2022-II-ADCP.pdf
# 1                     LK ADCP Q2 2022 - Final_Signed.pdf
# 2                                           instance.zip
# 3                   FinancialStatement-2022-II-ADCP.xlsx
# 4                                         inlineXBRL.zip
# ...                                                  ...
# 27683                                 SDP LK Q3 2022.pdf
# 27684       Q3 Report PT Zyrexindo Mandiri Buana Tbk.pdf
# 27685  Penjelasan Perubahan Aset - Liabilitas 30 Sep ...
# 27686                                       instance.zip
# 27687                                     inlineXBRL.zip
#
#                                                File_Path Report_Period  \
# 0      https://www.idx.co.id//Portals/0/StaticData/Li...           TW2
# 1      https://www.idx.co.id//Portals/0/StaticData/Li...           TW2
# 2      https://www.idx.co.id//Portals/0/StaticData/Li...           TW2
# 3      https://www.idx.co.id//Portals/0/StaticData/Li...           TW2
# 4      https://www.idx.co.id//Portals/0/StaticData/Li...           TW2
# ...                                                  ...           ...
# 27683  https://www.idx.co.id//Portals/0/StaticData/Li...           TW3
# 27684  https://www.idx.co.id//Portals/0/StaticData/Li...           TW3
# 27685  https://www.idx.co.id//Portals/0/StaticData/Li...           TW3
# 27686  https://www.idx.co.id//Portals/0/StaticData/Li...           TW3
# 27687  https://www.idx.co.id//Portals/0/StaticData/Li...           TW3
#
#       Report_Type Report_Year                      NamaEmiten  \
# 0             rdf        2022   PT Adhi Commuter Properti Tbk
# 1             rdf        2022   PT Adhi Commuter Properti Tbk
# 2             rdf        2022   PT Adhi Commuter Properti Tbk
# 3             rdf        2022   PT Adhi Commuter Properti Tbk
# 4             rdf        2022   PT Adhi Commuter Properti Tbk
# ...           ...         ...                             ...
# 27683         rdf        2022  PT Zyrexindo Mandiri Buana Tbk
# 27684         rdf        2022  PT Zyrexindo Mandiri Buana Tbk
# 27685         rdf        2022  PT Zyrexindo Mandiri Buana Tbk
# 27686         rdf        2022  PT Zyrexindo Mandiri Buana Tbk
# 27687         rdf        2022  PT Zyrexindo Mandiri Buana Tbk
#
#                      LastScraped
# 0     2023-03-19 20:14:59.187510
# 1     2023-03-19 20:14:59.187510
# 2     2023-03-19 20:14:59.187510
# 3     2023-03-19 20:14:59.187510
# 4     2023-03-19 20:14:59.187510
# ...                          ...
# 27683 2023-03-19 00:00:00.000000
# 27684 2023-03-19 00:00:00.000000
# 27685 2023-03-19 00:00:00.000000
# 27686 2023-03-19 00:00:00.000000
# 27687 2023-03-19 00:00:00.000000
#
# [27688 rows x 9 columns]

# %% [markdown]
# ## Append Previous Trading Day Data

# %% [markdown]
# ## Export to Excel

# %%
with pd.ExcelWriter('stocks.xlsx') as writer:
    CompanyProfilesDF.to_excel(writer, sheet_name='Company Profiles', index=False)
    TradingInfoDF.to_excel(writer, sheet_name='Trading Info', index=False)
    FinancialReportLinksDF.to_excel(writer, sheet_name='Financial Reports', index=False)
