# %% [markdown]
# Code History:
# 1. Version 1.0 (2023/03/09):
#     - Base version, working as expected

# %% [markdown]
# <strong>Features:</strong>
# - Scrape corporate and government bonds summary and details
#
# Data is scraped <strong>every weekday on 6PM GMT+7</strong>, few hours after the market has closed for the day. So the data you see before 6PM is previous trading day data.

# %%
import json
from json.decoder import JSONDecodeError
import numpy as np
import pandas as pd
import concurrent.futures
import time
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import queue
import threading
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import dateparser

# %% [markdown]
# # Chrome Selenium Starter
#
# Why Selenium? Because I need it to bypass cloudfare restriction

# %%
# Initialize the Chrome driver
options = Options()
options.add_argument("--headless=new")
driver = webdriver.Chrome(options=options)

# %% [markdown]
# # Scrape Bond Summary

# %% [markdown]
# ## BEI Bonds List

# %%
urls = {
    'Corporate Bond':'https://www.idx.co.id/secondary/get/BondSukuk/bond?pageSize=10000&indexFrom=1&bondType=1',
    'Goverment Bond':'https://www.idx.co.id/secondary/get/BondSukuk/bond?pageSize=10000&indexFrom=1&bondType=2'  
}

# %%
BEIBondsListDF = pd.DataFrame()
for issuer_type in urls:
    print(issuer_type)
    driver.get(urls[issuer_type])
    WebDriverWait(driver, timeout=10).until(lambda d: d.find_element(By.TAG_NAME, 'body'))
    BEIBondsListContent = driver.find_element(By.TAG_NAME, value='body').text
    BEIBondsTypeListDF = pd.DataFrame(json.loads(BEIBondsListContent)['Results']).drop(columns='Nomor')
    BEIBondsTypeListDF['IssuerType'] = issuer_type
    
    BEIBondsListDF = pd.concat([BEIBondsListDF, BEIBondsTypeListDF])
    
BEIBondsListDF['MatureDate'] = pd.to_datetime(BEIBondsListDF['MatureDate']).dt.normalize()
# Out:
# Corporate Bond
# Goverment Bond

# %%
BEIBondsListDF
# Out:
#          BondId                                           BondName IssuerCode  \
# 0    ABLS01XXMF              MTN Asian Bulk Logistics I Tahun 2022     ABLS-M
# 1       ABSM01C  Obligasi AB Sinar Mas Multifinance I Tahun 202...       ABSM
# 2       ADCP01B  Obligasi I Adhi Cummuter Properti Tahun 2021 S...       ADCP
# 3       ADCP02A  Obligasi II Adhi Commuter Properti Tahun 2022 ...       ADCP
# 4       ADCP02B  Obligasi II Adhi Commuter Properti Tahun 2022 ...       ADCP
# ..          ...                                                ...        ...
# 182      VR0091     Obligasi Negara Republik Indonesia Seri VR0091       GOVT
# 183      VR0092     Obligasi Negara Republik Indonesia Seri VR0092       GOVT
# 184      VR0093     Obligasi Negara Republik Indonesia Seri VR0093       GOVT
# 185      VR0094     Obligasi Negara Republik Indonesia Seri VR0094       GOVT
# 186      VR0095     Obligasi Negara Republik Indonesia Seri VR0095       GOVT
#
#     MatureDate Rating   Outstanding      IssuerType
# 0   2027-06-21   None  1.000000e+12  Corporate Bond
# 1   2023-09-04   irA-  3.500000e+10  Corporate Bond
# 2   2024-05-20  idBBB  9.000000e+09  Corporate Bond
# 3   2023-05-31  idBBB  2.055000e+11  Corporate Bond
# 4   2025-05-24  idBBB  1.020000e+11  Corporate Bond
# ..         ...    ...           ...             ...
# 182 2030-12-29   None  2.334195e+12  Goverment Bond
# 183 2027-12-29   None  2.981024e+13  Goverment Bond
# 184 2028-12-29   None  2.981024e+13  Goverment Bond
# 185 2029-12-29   None  2.981024e+13  Goverment Bond
# 186 2030-12-29   None  2.981024e+13  Goverment Bond
#
# [1334 rows x 7 columns]

# %% [markdown]
# ## Close and Quit Driver

# %%
driver.quit()

# %% [markdown]
# # Scrape Bond Details

# %% [markdown]
# ## Get Bond Details Function

# %%
## Well, the website has a weird issue, i can access medium term notes with url intended for corporate / govt bonds
## MTN example: https://www.ksei.co.id/services/registered-securities/medium-term-notes/lc/ABLS01XXMF
## Different URL example: https://www.ksei.co.id/services/registered-securities/corporate-bonds/lc/ABLS01XXMF
## Try it and you can still access the medium term notes
# 'https://www.ksei.co.id/services/registered-securities/medium-term-notes/lc/ABLS01XXMF'
# 'https://www.ksei.co.id/services/registered-securities/government-bonds/lc/FR0037'

def get_bond_details(BondId):
    while True:
        try:
            url = 'https://www.ksei.co.id/services/registered-securities/corporate-bonds/lc/' + BondId
            response = requests.get(url)
            soup = BeautifulSoup(response.content, 'html.parser')

            data = {}

            # Find the dl tag with class="deflist deflist--with-colon"
            dl_tag = soup.find('dl', class_='deflist deflist--with-colon')

            # Loop through all dt tags within the dl tag and get their text values
            dt_tags = dl_tag.find_all('dt')
            for dt in dt_tags:
                # Get the text value of the dt tag
                dt_text = dt.get_text(strip=True)
                # Get the corresponding dd tag and its text value
                # find_next_sibling is actually an important function and it's new for me xD
                dd_text = dt.find_next_sibling('dd').get_text(strip=True)
                # Add the dd_text to the data dictionary with the dt_text as the key
                data[dt_text] = dd_text
            break
        except AttributeError:
            print(url, 'attribute error, will retry!')
    
    time.sleep(2)

    return data

# %% [markdown]
# ## Multithreading with Progress Bar

# %%
df_list = []

with concurrent.futures.ThreadPoolExecutor(max_workers=7) as executor:
    futures = []
    for BondId in BEIBondsListDF['BondId']:
        future = executor.submit(get_bond_details, BondId)
        futures.append(future)
    
    # Use tqdm to add a progress bar to the multithreading process
    for future in tqdm(concurrent.futures.as_completed(futures), total=len(BEIBondsListDF['BondId'])):
        df_list.append(future.result())
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1334/1334 [08:45<00:00,  2.54it/s]

# %% [markdown]
# ## Join All Bond Details and Cleaning

# %% [markdown]
# ### Join Bond Details

# %%
BondDetailsDF = pd.DataFrame(df_list)
BondDetailsDF
# Out:
#                                           Security name  \
# 0     OBLIGASI BERKELANJUTAN II ADHI KARYA TAHAP II ...
# 1     OBLIGASI II ADHI COMMUTER PROPERTI TAHUN 2022 ...
# 2     OBLIGASI BERKELANJUTAN III ADHI KARYA TAHAP II...
# 3                 MTN ASIAN BULK LOGISTICS I TAHUN 2022
# 4     OBLIGASI AB SINAR MAS MULTIFINANCE I TAHUN 202...
# ...                                                 ...
# 1329     OBLIGASI NEGARA REPUBLIK INDONESIA SERI VR0090
# 1330     OBLIGASI NEGARA REPUBLIK INDONESIA SERI VR0091
# 1331     OBLIGASI NEGARA REPUBLIK INDONESIA SERI VR0093
# 1332     OBLIGASI NEGARA REPUBLIK INDONESIA SERI VR0094
# 1333     OBLIGASI NEGARA REPUBLIK INDONESIA SERI VR0095
#
#                               Issuer     ISIN Code  Short Code  \
# 0       ADHI KARYA (PERSERO) Tbk, PT  IDA0000984B5  ADHI02BCN2
# 1     ADHI COMMUTER PROPERTI Tbk, PT  IDA0001241A1     ADCP02A
# 2       ADHI KARYA (PERSERO) Tbk, PT  IDA0001239A5  ADHI03ACN3
# 3           ASIAN BULK LOGISTICS, PT  IDH000071307  ABLS01XXMF
# 4      AB SINAR MAS MULTIFINANCE, PT  IDA0001097C3     ABSM01C
# ...                              ...           ...         ...
# 1329   PEMERINTAH REPUBLIK INDONESIA  IDG000022500      VR0090
# 1330   PEMERINTAH REPUBLIK INDONESIA  IDG000022609      VR0091
# 1331   PEMERINTAH REPUBLIK INDONESIA  IDG000022807      VR0093
# 1332   PEMERINTAH REPUBLIK INDONESIA  IDG000022906      VR0094
# 1333   PEMERINTAH REPUBLIK INDONESIA  IDG000023003      VR0095
#
#                   Type       Listing Date Stock Exchange  Status  \
# 0       Straight Bonds       26 Juni 2019            IDX  Active
# 1       Straight Bonds        25 Mei 2022            IDX  Active
# 2       Straight Bonds        25 Mei 2022            IDX  Active
# 3                  MTN                  -              -  Active
# 4       Straight Bonds  07 September 2020            IDX  Active
# ...                ...                ...            ...     ...
# 1329  Government Bonds   30 Desember 2022            IDX  Active
# 1330  Government Bonds   30 Desember 2022            IDX  Active
# 1331  Government Bonds   30 Desember 2022            IDX  Active
# 1332  Government Bonds   30 Desember 2022            IDX  Active
# 1333  Government Bonds   30 Desember 2022            IDX  Active
#
#                     Nominal         Current Amount  ... Interest/Disc Rate  \
# 0        473,500,000,000.00     473,500,000,000.00  ...              9.75%
# 1        205,500,000,000.00                   0.00  ...                10%
# 2      1,286,200,000,000.00                   0.00  ...              8.25%
# 3      1,000,000,000,000.00   1,000,000,000,000.00  ...                 9%
# 4         35,000,000,000.00                   0.00  ...                11%
# ...                     ...                    ...  ...                ...
# 1329   2,334,195,000,000.00   2,334,195,000,000.00  ...           6.25682%
# 1330   2,334,195,000,000.00   2,334,195,000,000.00  ...           6.25682%
# 1331  29,810,235,000,000.00  29,810,235,000,000.00  ...           6.25682%
# 1332  29,810,235,000,000.00  29,810,235,000,000.00  ...           6.25682%
# 1333  29,810,235,000,000.00  29,810,235,000,000.00  ...           6.25682%
#
#           Interest Type Interest Frequency Currency        Form  \
# 0                 FIXED           3 MONTHS      IDR  Electronic
# 1                 FIXED           3 MONTHS      IDR  Electronic
# 2                 FIXED           3 MONTHS      IDR  Electronic
# 3                 Fixed           3 MONTHS      IDR  Electronic
# 4                 FIXED           3 MONTHS      IDR  Electronic
# ...                 ...                ...      ...         ...
# 1329  Floating/Variable           3 MONTHS      IDR  Electronic
# 1330  Floating/Variable           3 MONTHS      IDR  Electronic
# 1331  Floating/Variable           3 MONTHS      IDR  Electronic
# 1332  Floating/Variable           3 MONTHS      IDR  Electronic
# 1333  Floating/Variable           3 MONTHS      IDR  Electronic
#
#      Effective Date ISIN Day Count Basis           Activity Sector  \
# 0                      -               -     BUILDING CONSTRUCTION
# 1                      -               -  PROPERTY AND REAL ESTATE
# 2                      -               -     BUILDING CONSTRUCTION
# 3                      -               -            TRANSPORTATION
# 4                      -               -     FINANCIAL INSTITUTION
# ...                  ...             ...                       ...
# 1329                   -               -                       NaN
# 1330                   -               -                       NaN
# 1331                   -               -                       NaN
# 1332                   -               -                       NaN
# 1333                   -               -                       NaN
#
#      Number of Securities Exercise Price
# 0               0 (Total)            NaN
# 1               0 (Total)            NaN
# 2               0 (Total)            NaN
# 3               0 (Total)            NaN
# 4               0 (Total)            NaN
# ...                   ...            ...
# 1329            0 (Total)            NaN
# 1330            0 (Total)            NaN
# 1331            0 (Total)            NaN
# 1332            0 (Total)            NaN
# 1333            0 (Total)            NaN
#
# [1334 rows x 21 columns]

# %%
BondDetailsDF.columns
# Out:
# Index(['Security name', 'Issuer', 'ISIN Code', 'Short Code', 'Type',
#        'Listing Date', 'Stock Exchange', 'Status', 'Nominal', 'Current Amount',
#        'Mature Date', 'Interest/Disc Rate', 'Interest Type',
#        'Interest Frequency', 'Currency', 'Form', 'Effective Date ISIN',
#        'Day Count Basis', 'Activity Sector', 'Number of Securities',
#        'Exercise Price'],
#       dtype='object')

# %% [markdown]
# ### Data Transformation
#
# 1. Some dates are written in Indonesian format string, 'May' is written as 'Mei', so I use dateparser library to tackle this issue and convert it to pandas datetime column
# 2. Interest rate format is string, convert it to float32
# 3. Replace '-' string with NaN

# %%
BondDetailsDF['Listing Date'] = BondDetailsDF['Listing Date'].apply(lambda x: dateparser.parse(x) if x != '-' else np.nan)
BondDetailsDF['Mature Date'] = BondDetailsDF['Mature Date'].apply(lambda x: dateparser.parse(x) if x != '-' else np.nan)
BondDetailsDF['Effective Date ISIN'] = BondDetailsDF['Effective Date ISIN'].apply(lambda x: dateparser.parse(x) if x != '-' else np.nan)
BondDetailsDF['Interest/Disc Rate'] = BondDetailsDF['Interest/Disc Rate'].replace('%', '', regex=True).apply('float32')
BondDetailsDF = BondDetailsDF.replace('-', np.nan)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 BondDetailsDF['Listing Date'] = BondDetailsDF['Listing Date'].apply(lambda x: dateparser.parse(x) if x != '-' else np.nan)
# ----> 2 BondDetailsDF['Mature Date'] = BondDetailsDF['Mature Date'].apply(lambda x: dateparser.parse(x) if x != '-' else np.nan)
#       3 BondDetailsDF['Effective Date ISIN'] = BondDetailsDF['Effective Date ISIN'].apply(lambda x: dateparser.parse(x) if x != '-' else np.nan)
#       4 BondDetailsDF['Interest/Disc Rate'] = BondDetailsDF['Interest/Disc Rate'].replace('%', '', regex=True).apply('float32')
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[11], line 2, in <lambda>(x)
#       1 BondDetailsDF['Listing Date'] = BondDetailsDF['Listing Date'].apply(lambda x: dateparser.parse(x) if x != '-' else np.nan)
# ----> 2 BondDetailsDF['Mature Date'] = BondDetailsDF['Mature Date'].apply(lambda x: dateparser.parse(x) if x != '-' else np.nan)
#       3 BondDetailsDF['Effective Date ISIN'] = BondDetailsDF['Effective Date ISIN'].apply(lambda x: dateparser.parse(x) if x != '-' else np.nan)
#       4 BondDetailsDF['Interest/Disc Rate'] = BondDetailsDF['Interest/Disc Rate'].replace('%', '', regex=True).apply('float32')
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\dateparser\conf.py:92, in apply_settings.<locals>.wrapper(*args, **kwargs)
#      89 if not isinstance(kwargs['settings'], Settings):
#      90     raise TypeError("settings can only be either dict or instance of Settings class")
# ---> 92 return f(*args, **kwargs)
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\dateparser\__init__.py:61, in parse(date_string, date_formats, languages, locales, region, settings, detect_languages_function)
#      57 if languages or locales or region or detect_languages_function or not settings._default:
#      58     parser = DateDataParser(languages=languages, locales=locales,
#      59                             region=region, settings=settings, detect_languages_function=detect_languages_function)
# ---> 61 data = parser.get_date_data(date_string, date_formats)
#      63 if data:
#      64     return data['date_obj']
#
# File ~\anaconda3\envs\web_scraping\lib\site-packages\dateparser\date.py:442, in DateDataParser.get_date_data(self, date_string, date_formats)
#     399 """
#     400 Parse string representing date and/or time in recognizable localized formats.
#     401 Supports parsing multiple languages and timezones.
#    (...)
#     439
#     440 """
#     441 if not isinstance(date_string, str):
# --> 442     raise TypeError('Input type must be str')
#     444 res = parse_with_formats(date_string, date_formats or [], self._settings)
#     445 if res['date_obj']:
#
# TypeError: Input type must be str

# %%
BondDetailsDF.describe(include='all')

# %% [markdown]
# ### Drop Unnecessary Columns
#
# 1. Every column dropped has only a few value

# %%
BondDetailsDF = BondDetailsDF.drop(columns=['Current Amount', 'Effective Date ISIN', 'Day Count Basis', 'Exercise Price'])

# %% [markdown]
# ## Export to Excel

# %%
BondDetailsDF.to_excel('bonds.xlsx', index=False)
